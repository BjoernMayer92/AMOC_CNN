# %% [markdown]
# # 1 Import Packages

# %%
import xarray as xr
import numpy as np
import os

import src.config as config
import src.utils as utils

from tqdm import tqdm

import matplotlib.pyplot as plt
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
# Out:
# 2023-02-09 11:25:15.357300: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 2 Metadata

# %%
ml_transform_path = os.path.join(config.data_pro_path,"ml_transform")

# %%
lev_index = 0

# %%
train_x_filename = "train_data_stack_lonlatstandardized.nc"
valid_x_filename = "valid_data_stack_lonlatstandardized.nc"

train_y_filename = "train_data_amoc_depth_1020_lat_26_samplestandardized.nc"
valid_y_filename = "valid_data_amoc_depth_1020_lat_26_samplestandardized.nc"

# %% [markdown]
# # 3 Load Data

# %%
train_x_xr = xr.open_dataset(os.path.join(ml_transform_path, train_x_filename)).isel(lev=lev_index)
valid_x_xr = xr.open_dataset(os.path.join(ml_transform_path, valid_x_filename)).isel(lev=lev_index)

# %%
train_y_xr = xr.open_dataset(os.path.join(ml_transform_path, train_y_filename))
valid_y_xr = xr.open_dataset(os.path.join(ml_transform_path, valid_y_filename))

# %%
train_data_amoc_depth_1020_lat_26_samplestd  = xr.load_dataset(os.path.join(ml_transform_path,"train_data_amoc_depth_1020_lat_26_samplestd.nc" ))
train_data_amoc_depth_1020_lat_26_samplemean = xr.load_dataset(os.path.join(ml_transform_path,"train_data_amoc_depth_1020_lat_26_samplemean,nc"))

# %% [markdown]
# # 4 Processing

# %%
train_x_xr_stack = train_x_xr.stack(sample=("realization","time"))
valid_x_xr_stack = valid_x_xr.stack(sample=("realization","time"))

# %%
train_y_xr_stack = train_y_xr.stack(sample=("realization","time"))
valid_y_xr_stack = valid_y_xr.stack(sample=("realization","time"))

# %%
valid_sample_coords = valid_y_xr_stack.sample
train_sample_coords = train_y_xr_stack.sample

train_x_ml_np = np.nan_to_num(np.expand_dims(train_x_xr_stack["rho"].transpose("sample",...).values,3),0)
valid_x_ml_np = np.nan_to_num(np.expand_dims(valid_x_xr_stack["rho"].transpose("sample",...).values,3),0)

train_y_ml_np = train_y_xr_stack["atlantic_moc"].values
valid_y_ml_np = valid_y_xr_stack["atlantic_moc"].values

# %%
train_batch_size = int(train_x_ml_.shape[0]/4)
valid_batch_size = valid_x_ml_pt.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train_batch_size = int(train_x_ml_.shape[0]/4)
#       2 valid_batch_size = valid_x_ml_pt.shape[0]
#
# NameError: name 'train_x_ml_' is not defined

# %%
train_dataset = TensorDataset(train_x_ml_pt, train_y_ml_pt)  
valid_dataset = TensorDataset(valid_x_ml_pt, valid_y_ml_pt)
data_train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True)
data_valid_loader = DataLoader(valid_dataset, batch_size=valid_batch_size, shuffle=True)

# %% [markdown]
# # 5 Model

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Conv2D(64,(4,4), activation="tanh", padding="same",input_shape=(120,121,1)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(tf.keras.layers.Conv2D(32,(4,4), activation="tanh", padding="same", input_shape=(60,60,64)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(tf.keras.layers.Conv2D(16,(4,4), activation="tanh", padding="same", input_shape=(30,30,32)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(8, activation="tanh"))

model.add(tf.keras.layers.Dense(1, activation="linear"))

# %%
tmp = model.get_weights()[0][:,:,0,63]

vmax = np.abs(tmp).max()

plot = plt.pcolormesh(tmp, vmin = -vmax, vmax=vmax, cmap="RdBu_r")

plt.colorbar(plot)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 120, 121, 64)      1088
#
#  max_pooling2d_5 (MaxPooling  (None, 60, 60, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 60, 60, 32)        32800
#
#  max_pooling2d_6 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 30, 30, 16)        8208
#
#  max_pooling2d_7 (MaxPooling  (None, 15, 15, 16)       0
#  2D)
#
#  flatten_2 (Flatten)         (None, 3600)              0
#
#  dense_4 (Dense)             (None, 8)                 28808
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 70,913
# Trainable params: 70,913
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
model.compile(optimizer = "adam", loss=tf.keras.losses.mse)

# %%
model.fit(x=train_x_ml_np, y=train_y_ml_np, batch_size=2000, epochs=100, validation_data=(valid_x_ml_np, valid_y_ml_np) )
# Out:
# Train on 7800 samples, validate on 1560 samples
# Epoch 1/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3802 - val_loss: 0.3726
# Epoch 2/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3872 - val_loss: 0.3725
# Epoch 3/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3767 - val_loss: 0.3938
# Epoch 4/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3715 - val_loss: 0.3698
# Epoch 5/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3743 - val_loss: 0.3686
# Epoch 6/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3719 - val_loss: 0.3838
# Epoch 7/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3901 - val_loss: 0.3702
# Epoch 8/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3698 - val_loss: 0.4079
# Epoch 9/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3740 - val_loss: 0.3775
# Epoch 10/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3632 - val_loss: 0.3645
# Epoch 11/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3751 - val_loss: 0.3661
# Epoch 12/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3611 - val_loss: 0.3649
# Epoch 13/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3614 - val_loss: 0.3659
# Epoch 14/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3542 - val_loss: 0.3619
# Epoch 15/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3526 - val_loss: 0.3898
# Epoch 16/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3704 - val_loss: 0.3879
# Epoch 17/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3987 - val_loss: 0.4076
# Epoch 18/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3773 - val_loss: 0.4129
# Epoch 19/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3870 - val_loss: 0.4579
# Epoch 20/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3914 - val_loss: 0.3585
# Epoch 21/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3651 - val_loss: 0.4170
# Epoch 22/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.4032 - val_loss: 0.4132
# Epoch 23/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3825 - val_loss: 0.3776
# Epoch 24/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3563 - val_loss: 0.3565
# Epoch 25/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3560 - val_loss: 0.3805
# Epoch 26/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3670 - val_loss: 0.3638
# Epoch 27/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3542 - val_loss: 0.3861
# Epoch 28/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3515 - val_loss: 0.3542
# Epoch 29/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3437 - val_loss: 0.3560
# Epoch 30/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3395 - val_loss: 0.3604
# Epoch 31/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3390 - val_loss: 0.3512
# Epoch 32/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3369 - val_loss: 0.3511
# Epoch 33/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3360 - val_loss: 0.3499
# Epoch 34/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3346 - val_loss: 0.3682
# Epoch 35/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3368 - val_loss: 0.3610
# Epoch 36/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3379 - val_loss: 0.3483
# Epoch 37/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3334 - val_loss: 0.3473
# Epoch 38/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3358 - val_loss: 0.3701
# Epoch 39/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3391 - val_loss: 0.3653
# Epoch 40/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3361 - val_loss: 0.3726
# Epoch 41/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3362 - val_loss: 0.3627
# Epoch 42/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3455 - val_loss: 0.4369
# Epoch 43/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3514 - val_loss: 0.3486
# Epoch 44/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3394 - val_loss: 0.3449
# Epoch 45/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3360 - val_loss: 0.3521
# Epoch 46/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3296 - val_loss: 0.3465
# Epoch 47/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3216 - val_loss: 0.3485
# Epoch 48/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3195 - val_loss: 0.3425
# Epoch 49/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3167 - val_loss: 0.3421
# Epoch 50/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3190 - val_loss: 0.3496
# Epoch 51/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3249 - val_loss: 0.3542
# Epoch 52/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3187 - val_loss: 0.3483
# Epoch 53/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3442 - val_loss: 0.3569
# Epoch 54/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3698 - val_loss: 0.3402
# Epoch 55/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3424 - val_loss: 0.3542
# Epoch 56/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3269 - val_loss: 0.3616
# Epoch 57/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3348 - val_loss: 0.3615
# Epoch 58/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3234 - val_loss: 0.3483
# Epoch 59/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3156 - val_loss: 0.3414
# Epoch 60/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3378 - val_loss: 0.3410
# Epoch 61/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3200 - val_loss: 0.3542
# Epoch 62/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3224 - val_loss: 0.3713
# Epoch 63/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3216 - val_loss: 0.3444
# Epoch 64/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3110 - val_loss: 0.3376
# Epoch 65/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3040 - val_loss: 0.3357
# Epoch 66/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3026 - val_loss: 0.3387
# Epoch 67/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3043 - val_loss: 0.3401
# Epoch 68/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3011 - val_loss: 0.3401
# Epoch 69/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3223 - val_loss: 0.3412
# Epoch 70/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3040 - val_loss: 0.3375
# Epoch 71/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3051 - val_loss: 0.3333
# Epoch 72/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3016 - val_loss: 0.3764
# Epoch 73/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3376 - val_loss: 0.3472
# Epoch 74/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3143 - val_loss: 0.3324
# Epoch 75/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2982 - val_loss: 0.3317
# Epoch 76/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3285 - val_loss: 0.3562
# Epoch 77/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3149 - val_loss: 0.3742
# Epoch 78/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3043 - val_loss: 0.3355
# Epoch 79/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2932 - val_loss: 0.3378
# Epoch 80/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2981 - val_loss: 0.3480
# Epoch 81/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3066 - val_loss: 0.3716
# Epoch 82/100
# 7800/7800 [==============================] - 9s 1ms/sample - loss: 0.3119 - val_loss: 0.3678
# Epoch 83/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3122 - val_loss: 0.3292
# Epoch 84/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2943 - val_loss: 0.3477
# Epoch 85/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3022 - val_loss: 0.3841
# Epoch 86/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3040 - val_loss: 0.3422
# Epoch 87/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3017 - val_loss: 0.3307
# Epoch 88/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2886 - val_loss: 0.3292
# Epoch 89/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2886 - val_loss: 0.3292
# Epoch 90/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3210 - val_loss: 0.4002
# Epoch 91/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3210 - val_loss: 0.4300
# Epoch 92/100
# 7800/7800 [==============================] - 9s 1ms/sample - loss: 0.3297 - val_loss: 0.3897
# Epoch 93/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3146 - val_loss: 0.3430
# Epoch 94/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.3143 - val_loss: 0.3390
# Epoch 95/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2976 - val_loss: 0.3259
# Epoch 96/100
# 7800/7800 [==============================] - 9s 1ms/sample - loss: 0.2860 - val_loss: 0.3269
# Epoch 97/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2980 - val_loss: 0.3312
# Epoch 98/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2921 - val_loss: 0.3262
# Epoch 99/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2803 - val_loss: 0.3396
# Epoch 100/100
# 7800/7800 [==============================] - 10s 1ms/sample - loss: 0.2866 - val_loss: 0.3255

# %%
plt.plot(model.history.history["loss"])
plt.plot(model.history.history["val_loss"])

# %%
model.predict(train_x_ml_np)
# Out:
# array([[ 0.87890667],
#        [ 1.3494039 ],
#        [ 1.0303066 ],
#        ...,
#        [ 0.27815604],
#        [-0.20429206],
#        [ 0.16027749]], dtype=float32)

# %%
model.get_layer()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 model.get_layer()
#
# File /work/uo1075/u301101/programming/miniconda3/envs/CNN/lib/python3.8/site-packages/keras/engine/training.py:3279, in Model.get_layer(self, name, index)
#    3274             return layer
#    3275     raise ValueError(
#    3276         f"No such layer: {name}. Existing layers are: "
#    3277         f"{list(layer.name for layer in self.layers)}."
#    3278     )
# -> 3279 raise ValueError(
#    3280     "Provide either a layer name or layer index at " "`get_layer`."
#    3281 )
#
# ValueError: Provide either a layer name or layer index at `get_layer`.

# %%
model.input
# Out:
# <tf.Tensor 'conv2d_5_input:0' shape=(None, 120, 121, 1) dtype=float32>

# %%
model.get_layer("conv2d_5")

# %%
model.layers
# Out:
# [<keras.layers.convolutional.conv2d.Conv2D at 0x7fff89077220>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fff890772e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7fff8a2f7520>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fff890772b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x7fff8906a280>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x7fff89077c10>,
#  <keras.layers.reshaping.flatten.Flatten at 0x7fff8906cca0>,
#  <keras.layers.core.dense.Dense at 0x7fff890742e0>,
#  <keras.layers.core.dense.Dense at 0x7fff8900ac10>]

# %%
intermediate_layer_model = tf.keras.Model(inputs=model.input,outputs=model.get_layer("conv2d_5").output)

# %%
int_media_layer_pred = intermediate_layer_model.predict(train_x_ml_np)

# %%
tmp = int_media_layer_pred[0,:,:,0]

vmax = np.abs(tmp).max()

plt.pcolormesh(int_media_layer_pred[0,:,:,23], vmin=-vmax, vmax=vmax, cmap="RdBu_r")

# %%
plt.plot(y_train_true)
plt.plot(y_train_pred)

plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
y_train_pred = model.predict(train_x_ml_np)
y_train_true = train_y_ml_np

y_valid_pred = model.predict(valid_x_ml_np)
y_valid_true = valid_y_ml_np

# %%
plt.scatter(y_train_pred, y_train_true)
plt.scatter(y_valid_pred, y_valid_true)

plt.xlim(-4,4)
plt.ylim(-4,4)
plt.axhline(0)
plt.axvline(0)

# %%
import innvestigate

# %%
analyzer = innvestigate.create_analyzer("lrp.epsilon", model)

# %%
heatmaps = analyzer.analyze(train_x_ml_np[:,:,:,:])

# %%
tmp = heatmaps[700,:,:,0]

vmax = np.abs(tmp).max()

plot = plt.pcolormesh(tmp,vmin=-vmax, vmax=vmax,  cmap="RdBu_r")
plt.colorbar(plot)

# %%
fig, ax = plt.subplots(1,5, figsize=(25,5))

ax_ravel = np.ravel(ax)

for i, ax in enumerate(ax_ravel):
    ax = ax_ravel[i]
    tmp = activation["first_conv"][235,i]
    vmax= np.abs(tmp).max()
    
    plot = ax.pcolormesh(tmp, vmin=-vmax, vmax=vmax, cmap="RdBu_r")
    plt.colorbar(plot, ax = ax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 7
#       5 for i, ax in enumerate(ax_ravel):
#       6     ax = ax_ravel[i]
# ----> 7     tmp = activation["first_conv"][235,i]
#       8     vmax= np.abs(tmp).max()
#      10     plot = ax.pcolormesh(tmp, vmin=-vmax, vmax=vmax, cmap="RdBu_r")
#
# NameError: name 'activation' is not defined

# %% [markdown]
# # 8 LRP

# %%
import zennit

# %%
composite = zennit.composites.EpsilonPlusFlat()

# %%
composite.context(module = net)

# %%
torch.eye(1)[[0]]
# Out:
# tensor([[1.]])

# %%
with composite.context(net) as modified_model:
    output = modified_model(x_example[0,:])
    output.backward(gradient = torch.eye(1)[[0]])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[178], line 2
#       1 with composite.context(net) as modified_model:
# ----> 2     output = modified_model(x_example[0,:])
#       3     output.backward(gradient = torch.eye(1)[[0]])
#
# File /work/uo1075/u301101/programming/miniconda3/envs/CNN/lib/python3.8/site-packages/torch/nn/modules/module.py:1194, in _call_impl(self, *input, **kwargs)
#    1191     if '_is_full_backward_hook' not in self.__dict__:
#    1192         self._is_full_backward_hook = None
# -> 1194 def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
#    1195     if '_parameters' in self.__dict__:
#    1196         _parameters = self.__dict__['_parameters']
#
# Cell In[66], line 31, in ConvNet.forward(self, x)
#      27 #x = self.second_batch(x)
#      28
#      29 #x = self.third_conv(x)
#      30 x = x.reshape(x.shape[0], -1)
# ---> 31 x = self.first_fc(x)
#      32 x = torch.relu(x)
#      33 x = self.second_fc(x)
#
# File /work/uo1075/u301101/programming/miniconda3/envs/CNN/lib/python3.8/site-packages/torch/nn/modules/module.py:1212, in _call_impl(self, *input, **kwargs)
#    1211 def remove_from(*dicts_or_sets):
# -> 1212     for d in dicts_or_sets:
#    1213         if name in d:
#    1214             if isinstance(d, dict):
#
# File /work/uo1075/u301101/programming/miniconda3/envs/CNN/lib/python3.8/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (5x49 and 245x5)

# %%
with Gradient(model=net, composite=composite) as atributor:
    output, attribution = attributor(x_example, y_example)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 with Gradient(model=net, composite=composite) as atributor:
#       2     output, attribution = attributor(x_example, y_example)
#
# NameError: name 'Gradient' is not defined

# %%
torch.save(net.state_dict(),"model_state")

# %%
a.shape
# Out:
# (5, 1, 10, 10)

# %%
tmp = a[4,0]
vmax = np.abs(tmp).max()
plot = plt.pcolormesh(tmp, vmin = -vmax, vmax= vmax, cmap="RdBu_r")
plt.colorbar(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 tmp = a[4,0]
#       2 vmax = np.abs(tmp).max()
#       3 plot = plt.pcolormesh(tmp, vmin = -vmax, vmax= vmax, cmap="RdBu_r")
#
# NameError: name 'a' is not defined

# %%
plt.plot(valid_loss_arr)
plt.ylim(0,2)
# Out:
# (0.0, 2.0)

# %%
plt.plot(train_loss_arr)
plt.ylim(0,2)
# Out:
# (0.0, 2.0)

# %%
valid_loss_arr[-1]
# Out:
# array(0.4417853, dtype=float32)

# %%
y_train_pred = net(train_x_ml_pt).detach().numpy()
y_train_true = train_y_ml_pt.detach().numpy()

y_valid_pred = net(valid_x_ml_pt).detach().numpy()
y_valid_true = valid_y_ml_pt.detach().numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 y_train_pred = net(train_x_ml_pt).detach().numpy()
#       2 y_train_true = train_y_ml_pt.detach().numpy()
#       4 y_valid_pred = net(valid_x_ml_pt).detach().numpy()
#
# NameError: name 'net' is not defined

# %%
plt.scatter(y_train_pred, y_train_true)
plt.scatter(y_valid_pred, y_valid_true)

plt.xlim(-4,4)
plt.ylim(-4,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 plt.scatter(y_train_pred, y_train_true)
#       2 plt.scatter(y_valid_pred, y_valid_true)
#       4 plt.xlim(-4,4)
#
# NameError: name 'y_train_pred' is not defined
